# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
from pandas import DataFrame, Series
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from cStringIO import StringIO
from bs4 import BeautifulSoup
import urllib2
import urllib
import ast
import requests
from selenium import webdriver  
from selenium.common.exceptions import NoSuchElementException  
from selenium.webdriver.common.keys import Keys  
import time
import re
import json
import multiprocessing as mp
from HTMLParser import HTMLParser
import datetime
h = HTMLParser()

# %% [markdown]
# # Define basic functions used throughout

# %%
def isFloat(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

# %%
def flatten(foo):
    for x in foo:
        if hasattr(x, '__iter__'):
            for y in flatten(x):
                yield y
        else:
            yield x

# %% [markdown]
# # Create function to navigate through the built-in javascript calendar

# %%
def navigate_calendar(date, browser):
        
    yearidx = date.year%10 + 2
    monthidx = date.month
        
    # Click on current month to open up menu of all months
    browser.find_element_by_xpath('/html/body/div[5]/div[1]/table/thead/tr[1]/th[3]').click()
    time.sleep(.5)
    # Click current year
    browser.find_element_by_xpath('/html/body/div[5]/div[2]/table/thead/tr/th[2]').click()
    time.sleep(.5)
    
    if date < datetime.date(2010,1,1):
        # Click for previous decade (2000-2009)
        browser.find_element_by_xpath('/html/body/div[5]/div[3]/table/thead/tr/th[1]').click()
        time.sleep(.5)
    if date < datetime.date(2000,1,1):
        # Click for previous decade (1990-1999)
        browser.find_element_by_xpath('/html/body/div[5]/div[3]/table/thead/tr/th[1]').click()
        time.sleep(.5)
    # Click desired year within decade (span[2] gets 1990)
    browser.find_element_by_xpath('/html/body/div[5]/div[3]/table/tbody/tr/td/span[%d]' %yearidx).click()
    time.sleep(.5)
    # Click month (span[3] gets March)
    browser.find_element_by_xpath('/html/body/div[5]/div[2]/table/tbody/tr/td/span[%d]' %monthidx).click()
    time.sleep(.5)

# %% [markdown]
# # Pull auction IDs, names, dates, and department and save into dataframe
#
# This will be used to pull all individual auctions, with the ability to sort by department, date, and the specific auction it was sold in.
#
# Auction ID is crucial in the URL to identify which event the items were sold in.
#
# ### NOTE: As Sotheby's uses JS for their auctions, we will have to use selenium to create a mock browser in order to pull this information.

# %%
def pull_auction_ids_names_dates_viaDept(departmentNum, endDate, run):

    browser = webdriver.Firefox() 
    browser.maximize_window()
    browser.get('http://www.sothebys.com/en/auctions/results.html')  
    time.sleep(3)
    
    # Scroll a bit
    for i in range(0,5):
        browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/div[1]').send_keys(Keys.ARROW_DOWN)
        time.sleep(0.4)
    
    # Click on advanced search 
    browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[1]/div/a').click() 
    time.sleep(2)
    
    # Fix start date - 1/22/2000 is the first date where they start uploading auction data
    startDate = datetime.date(2000,1,22)
    browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[2]/div/label[1]/div/input').click()
    time.sleep(2)
    navigate_calendar(startDate, browser)
    time.sleep(2)
    # Select 1/22/2000 in calendar view
    browser.find_element_by_xpath('/html/body/div[5]/div[1]/table/tbody/tr[4]/td[6]').click()
    time.sleep(2)
    
    # Check to see if endDate needs to be updated and fix if so, create dataframe if first run
    if endDate != datetime.date.today():
        browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[2]/div/label[2]/div/input').click()
        time.sleep(2)
        browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[2]/div/label[2]/div/input').click()
        time.sleep(2)
        navigate_calendar(endDate, browser)
        time.sleep(2)
        browser.find_element_by_xpath('/html/body/div[5]/div[1]/table/tbody/tr[6]/td[7]').click()
        time.sleep(2)
    else:
        browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[2]/div/label[2]/div/input').click()
        time.sleep(2)
        browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[2]/div/label[2]/div/input').click()
        time.sleep(2)
        browser.find_element_by_xpath('/html/body/div[5]/div[1]/table/tbody/tr[2]/td[7]').click()
        time.sleep(2)
        allAuctions = pd.DataFrame()
    
    # Apply search parameters
    browser.find_element_by_xpath('//*[@id="apply-btn"]').click()
    time.sleep(5)
    
    # Open Department Dialog
    browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[1]/div/label[2]/div/button/span').click()
    time.sleep(2)
    
    # Select Department
    if departmentNum > 14:
        numScrolls = (departmentNum-5)//2
        scroll = 1
        for i in range(0,numScrolls):
            browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[1]/div/label[2]/div/ul/li[%d]/a/label' % scroll).send_keys(Keys.ARROW_DOWN)
            time.sleep(.25)
            scroll += 2
            
    if departmentNum > 60:
        browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[1]/div/label[2]/div/ul/li[59]/a/label').send_keys(Keys.ARROW_DOWN)
        time.sleep(.25)
        browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[1]/div/label[2]/div/ul/li[64]/a/label').send_keys(Keys.ARROW_DOWN)
    
    time.sleep(1)
                                      
    browser.find_element_by_xpath('//*[@id="bodyWrap"]/div[2]/section/form/div[1]/div/label[2]/div/ul/li[%d]/a/label' %departmentNum).click()
    time.sleep(3)
    
    # Press View All
    browser.find_element_by_xpath('//*[@id="AuctionList"]/div/div[1]/div[2]/a[3]/span').click()
    time.sleep(5)
    
    # Extract source and close web browser
    html_source = browser.page_source  

    # Load in data into BeautifulSoup
    soup = BeautifulSoup(html_source,'html.parser')  
    auctionList = soup.findAll('article',{'class':'AuctionListItem'})  
    
    auctions_df = pd.DataFrame()
    
    if run == 1:
        allAuctions = auctions_df
        
    anchor1 = "/en/auctions/"
    anchor2 = "title"
    anchor3 = "><img alt"
    anchor4 = "datetime"
    anchor5 = "</time>"
    
    # Find all auction IDs, names, dates
    
    for auction in auctionList:
        x = str(auction)
        x1 = x[x.find(anchor4)+len(anchor4)+3:x.find(anchor5)+1]
        auction_Id = x[x.find(anchor1)+len(anchor1)+5:x.find(anchor2)-7]
        auction_Name = x[x.find(anchor2)+7:x.find(anchor3)-1]
        auction_Date = x1[x1.find(">")+1:x1.find("<")]
        df2 = pd.DataFrame([[auction_Name, auction_Id, auction_Date]])
        
        # Exclude the auctions with no data ("Page not found")
        
        auctions_df = auctions_df.append(df2)

        
    # Format auctions dataframe
    
    auctions_df.columns = ['auctionName','auctionId','auctionDate']
    
    # Add to all other auctions of department
    
    allAuctions = allAuctions.append(auctions_df)
    
    # Return all auctions / rerun if haven't captured full category
    
    browser.quit()
    
    if auctions_df.shape[0]<500:
        allAuctions = allAuctions.drop_duplicates()
        allAuctions = allAuctions[allAuctions['auctionId'].map(lambda x: x[:5]) != 'logue']
        allAuctions.index = range(0,len(allAuctions))
        return allAuctions
    else:
        auctions.index = range(0,auctions.shape[0])
        newEndDate = auctions['auctionDate'][500*run-1]
        run += 1
        pull_auction_ids_names_dates_viaDept(departmentNum, newEndDate, run)

# %% [markdown]
# # Now that we have all of the auctions ever hosted by Sotheby's, let's pull the specific items presented at these auctions and the relevant information on them.

# %% [markdown]
# ### This function will allow us to open the page of a specific auction

# %%
def read_in_auction_source(auctionId, auctionYear):

#for year in range(2017,2018):
    query = str(auctionYear) + "/" + auctionId + ".html"
    testurl = "http://www.sothebys.com/en/auctions/" + query
    html_source_code = requests.get(testurl, headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.107 Safari/537.36','Upgrade-Insecure-Requests': '1','x-runtime': '148ms'}, allow_redirects=True).content

    soup = BeautifulSoup(html_source_code,'html.parser')
    soup_s = str(soup)

    testCase = "Page Not Found"

    #if soup_s[soup_s.find("<title>")+7:soup_s.find("<title>")+7+len(testCase)] != testCase:
        #break
            
    return soup

# %% [markdown]
# ### This function will permit us to pull the information on a specific item, including currency it was sold in, price it was sold for, etc.

# %%
def format_auction_data(soup_object, auctionName, auctionId, auctionDate):
    
    allLots = str(soup_object.find_all("script", type="text/javascript"))
    
    allLots = allLots[allLots.find('ECAT.lot['):allLots.find('cleanArray')]
    
    # There's an issue with the default input of the JSON object 
    # being in the improper formatting of booleans, fix.
    
    allLots = allLots.replace('false',"'False'")
    allLots = allLots.replace('true',"'True'")
    
    allLots = allLots.split('};')[:-1]
    
    # We had to split by '};' rather than just ';' as some of 
    # the strings within the JSON object properties contained semicolons.
    # Now we want to make sure that we retain the proper formatting by replacing the '}'
    
    allLots = [item + "}" for item in allLots]
    
    # Now we want to convert these objects to dictionaries so
    # that they are easier to access.
    
    allLots_d = []
    lotNum = 1

    for idx,item in enumerate(allLots):
        dig = len(str(lotNum))
        newDict = ast.literal_eval(item[13+dig:])
        allLots_d.append(newDict)
        lotNum += 1
        
    # Now we have all dictionaries held in a list, however we only 
    # need a fraction of the keys.

    newKeys = ['currency', 'highEst', 'lowEst', 'salePrice', 
               'title','guaranteeLine','genre','id','isSold',
               'medium','type']

    allLots_dn = allLots_d

    for idx, item in enumerate(allLots_dn):
        allLots_dn[idx] = {key: allLots_dn[idx][key] for key in newKeys}
        
    # Finally we should have our data in a format that is accessible. 
    # All dictionaries are held in a list of "allLots_dn".
    
    
    #### Can merge two for loops here and drop dataframe columns you're
    #### not using instead of dropping keys from dictionaries
    
    df = pd.DataFrame()

    for item in allLots_dn:
        df1 = pd.DataFrame(item.values()).transpose()
        df1.columns = item.keys()
        df = df.append(df1)

    df.index = range(0, len(df))
    df['auctionName'] = auctionName
    df['auctionId'] = auctionId
    df['auctionDate'] = auctionDate
    
    return df

# %%
def convert_auction_data(auctionName, auctionId, auctionDate, auctionYear):
    soupObj = read_in_auction_source(auctionId, auctionYear)
    auction_f = format_auction_data(soupObj,auctionName,auctionId, auctionDate)
    return auction_f

# %%
endDate = datetime.date(2017,4,19)
masterdf_AuctionEvents = pull_auction_ids_names_dates_viaDept(51, endDate, 1)

# %%
masterdf_AuctionEvents['auctionYear'] = masterdf_AuctionEvents['auctionDate'].apply(lambda x: int(x[-4:]))

# %%
def pull_items_from_auction(row, df=masterdf_AuctionEvents):

    print("Pulling auction " + str(row+1) + " of " + str(df.shape[0]))
    auctionId = df['auctionId'][row]
    auctionName = df['auctionName'][row]
    auctionDate = df['auctionDate'][row]
    auctionYear = df['auctionYear'][row]
    auctionData = convert_auction_data(auctionName, auctionId, auctionDate, auctionYear)
    return auctionData

# %%
masterdf_AuctionItems = pd.DataFrame()
numAuctions = masterdf_AuctionEvents.shape[0]
auctionData = []

# %%
if __name__ == '__main__':    
    
    pool = mp.Pool(mp.cpu_count())
    results = pool.map_async(pull_items_from_auction, range(0,numAuctions)).get(9999)
    masterdf_AuctionItems = pd.concat(results)
# Out:
# Pulling auction 1 of 126
# Pulling auction 9 of 126
# Pulling auction 17 of 126
# Pulling auction 25 of 126
# Pulling auction 10 of 126
# Pulling auction 18 of 126
# Pulling auction 11 of 126
# Pulling auction 2 of 126
# Pulling auction 12 of 126
# Pulling auction 26 of 126
# Pulling auction 19 of 126
# Pulling auction 3 of 126
# Pulling auction 4 of 126
# Pulling auction 13 of 126
# Pulling auction 27 of 126
# Pulling auction 5 of 126
# Pulling auction 14 of 126
# Pulling auction 15 of 126
# Pulling auction 20 of 126
# Pulling auction 6 of 126
# Pulling auction 16 of 126
# Pulling auction 7 of 126
# Pulling auction 28 of 126
# Pulling auction 33 of 126
# Pulling auction 29 of 126
# Pulling auction 8 of 126
# Pulling auction 34 of 126
# Pulling auction 30 of 126
# Pulling auction 35 of 126
# Pulling auction 41 of 126
# Pulling auction 21 of 126
# Pulling auction 36 of 126
# Pulling auction 31 of 126
# Pulling auction 42 of 126
# Pulling auction 22 of 126
# Pulling auction 43 of 126
# Pulling auction 32 of 126
# Pulling auction 23 of 126
# Pulling auction 44 of 126
# Pulling auction 45 of 126
# Pulling auction 49 of 126
# Pulling auction 24 of 126
# Pulling auction 37 of 126
# Pulling auction 46 of 126
# Pulling auction 57 of 126
# Pulling auction 50 of 126
# Pulling auction 51 of 126
# Pulling auction 47 of 126
# Pulling auction 58 of 126
# Pulling auction 38 of 126
# Pulling auction 52 of 126
# Pulling auction 48 of 126
# Pulling auction 39 of 126
# Pulling auction 40 of 126
# Pulling auction 65 of 126
# Pulling auction 53 of 126
# Pulling auction 59 of 126
# Pulling auction 73 of 126
# Pulling auction 60 of 126
# Pulling auction 66 of 126
# Pulling auction 74 of 126
# Pulling auction 54 of 126
# Pulling auction 61 of 126
# Pulling auction 67 of 126
# Pulling auction 55 of 126
# Pulling auction 68 of 126
# Pulling auction 62 of 126
# Pulling auction 75 of 126
# Pulling auction 56 of 126
# Pulling auction 69 of 126
# Pulling auction 76 of 126
# Pulling auction 63 of 126
# Pulling auction 81 of 126
# Pulling auction 77 of 126
# Pulling auction 64 of 126
# Pulling auction 82 of 126
# Pulling auction 70 of 126
# Pulling auction 83 of 126
# Pulling auction 78 of 126
# Pulling auction 89 of 126
# Pulling auction 90 of 126
# Pulling auction 79 of 126
# Pulling auction 71 of 126
# Pulling auction 91 of 126
# Pulling auction 72 of 126
# Pulling auction 84 of 126
# Pulling auction 92 of 126
# Pulling auction 80 of 126
# Pulling auction 85 of 126
# Pulling auction 97 of 126
# Pulling auction 105 of 126
# Pulling auction 93 of 126
# Pulling auction 86 of 126
# Pulling auction 98 of 126
# Pulling auction 106 of 126
# Pulling auction 94 of 126
# Pulling auction 87 of 126
# Pulling auction 107 of 126
# Pulling auction 99 of 126
# Pulling auction 95 of 126
# Pulling auction 88 of 126
# Pulling auction 100 of 126
# Pulling auction 96 of 126
# Pulling auction 108 of 126
# Pulling auction 101 of 126
# Pulling auction 113 of 126
# Pulling auction 121 of 126
# Pulling auction 109 of 126
# Pulling auction 102 of 126
# Pulling auction 114 of 126
# Pulling auction 122 of 126
# Pulling auction 110 of 126
# Pulling auction 123 of 126
# Pulling auction 115 of 126
# Pulling auction 103 of 126
# Pulling auction 124 of 126
# Pulling auction 125 of 126
# Pulling auction 126 of 126
# Pulling auction 111 of 126
# Pulling auction 116 of 126
# Pulling auction 104 of 126
# Pulling auction 112 of 126
# Pulling auction 117 of 126
# Pulling auction 118 of 126
# Pulling auction 119 of 126
# Pulling auction 120 of 126

# %% [markdown]
# # We should now have a dataframe with all of the items ever auctioned by Sotheby's from the year 2000 to present.
#
# ### Let's now format this properly and add a couple helpful columns

# %%
def format_aux_cols(df):
    df['auctionYear'] = df['auctionDate'].apply(lambda x: int(x[-4:]))

    for column in ['highEst', 'lowEst', 'salePrice']:
        df[column] = df[column].apply(lambda x: int(x))

    df.index = range(0,len(df))
    df['lot_desc'] = ""

# %%
format_aux_cols(masterdf_AuctionItems)

# %% [markdown]
# # We're missing a lot of information on the items themselves. Let's extract their descriptions to obtain further information.

# %%
auctionId = 'american-art-n09633'
lot = 2
auctionYear = 2017

# %%
    query = str(auctionYear) + '/' + auctionId + '/' + 'lot.' + str(lot) + '.html'
    testurl = 'http://www.sothebys.com/en/auctions/ecatalogue/' + query
    html_source_code = requests.get(testurl, headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.107 Safari/537.36','Upgrade-Insecure-Requests': '1','x-runtime': '148ms'}, allow_redirects=True).content

    soup = BeautifulSoup(html_source_code, "lxml")

    soup_s = str(soup)

    unwanted_tags = ['<br>','<br/>',
                     '<em>','</em>',
                     '<span>','</span>',
                     '<p>','</p>',
                     '<h1>','</h1>',
                     '<h2>','</h2>',
                     '<h3>','</h3>',
                     '<h4>','</h4>',
                     '<h5>','</h5>',
                     '<strong>','</strong>']
    
    for item in unwanted_tags:
        soup_s = soup_s.replace(item,'\n')

    soup_s = ''.join(i for i in soup_s if ord(i)<128)
    
    for line in soup_s:
        line = line.strip()
        line = line.encode("utf-8", 'i')

# %%
    anchor0a = '<img class="lot-image" data-src="'
    anchor0a_idx = soup_s.find(anchor0a)+len(anchor0a)
    anchor0b = '" id="image-zoom" src=""/>'
    anchor0b_idx = soup_s.find(anchor0b)

    url_precursor = "http://www.sothebys.com"
    img_url = url_precursor + soup_s[anchor0a_idx:anchor0b_idx]

# %%
img_url
# Out:
# 'http://www.sothebys.com data-src="/content/dam/stb/lots/N09/N09633/006N0963.jpg'

# %%
    img_data = requests.get(img_url, headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.107 Safari/537.36','Upgrade-Insecure-Requests': '1','x-runtime': '148ms'}, allow_redirects=True).content
    img_name = str(auctionId) + str(lot) + '.jpg'
    with open(img_name, 'wb') as handler:
        handler.write(img_data)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-152-fc78caf2762d> in <module>()
# ----> 1 img_data = requests.get(img_url, headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.107 Safari/537.36','Upgrade-Insecure-Requests': '1','x-runtime': '148ms'}, allow_redirects=True).content
#       2 img_name = str(auctionId) + str(lot) + '.jpg'
#       3 with open(img_name, 'wb') as handler:
#       4     handler.write(img_data)
#
# //anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# //anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# //anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# //anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# //anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.sothebys.com%20data-src=%22', port=80): Max retries exceeded with url: /content/dam/stb/lots/N09/N09633/006N0963 (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x11c1b5450>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
extract_lot_description(1, 'american-art-n09633', 2017)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-145-7f37f8f33bf3> in <module>()
# ----> 1 extract_lot_description(1, 'american-art-n09633', 2017)
#
# <ipython-input-143-076d0dd1fd67> in extract_lot_description(lot, auctionId, auctionYear)
#      39     img_url = url_precursor + qq[anchor0a_idx:anchor0b_idx]
#      40
# ---> 41     img_data = requests.get(img_url, headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.107 Safari/537.36','Upgrade-Insecure-Requests': '1','x-runtime': '148ms'}, allow_redirects=True).content
#      42     img_name = str(auctionId) + str(lot) + '.jpg'
#      43     with open(img_name, 'wb') as handler:
#
# //anaconda/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# //anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# //anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# //anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# //anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.sothebys.com%3e%0a%3c', port=80): Max retries exceeded with url: /div%3E%0A%3C/div%3E%0A%3Cdiv%20id=%22image-zoom-wrapper%22%3E%0A%3Cimg%20c (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x117c931d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
def extract_lot_description(lot, auctionId, auctionYear):

    query = str(auctionYear) + '/' + auctionId + '/' + 'lot.' + str(lot) + '.html'
    testurl = 'http://www.sothebys.com/en/auctions/ecatalogue/' + query
    html_source_code = requests.get(testurl, headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.107 Safari/537.36','Upgrade-Insecure-Requests': '1','x-runtime': '148ms'}, allow_redirects=True).content

    soup = BeautifulSoup(html_source_code, "lxml")

    soup_s = str(soup)

    unwanted_tags = ['<br>','<br/>',
                     '<em>','</em>',
                     '<span>','</span>',
                     '<p>','</p>',
                     '<h1>','</h1>',
                     '<h2>','</h2>',
                     '<h3>','</h3>',
                     '<h4>','</h4>',
                     '<h5>','</h5>',
                     '<strong>','</strong>']
    
    for item in unwanted_tags:
        soup_s = soup_s.replace(item,'\n')

    soup_s = ''.join(i for i in soup_s if ord(i)<128)
    
    for line in soup_s:
        line = line.strip()
        line = line.encode("utf-8", 'i')
        
        
    # This block simultaneously downloads the image to the lib directory.
    anchor0a = '<img class="lot-image" data-src="'
    anchor0a_idx = soup_s.find(anchor0a)+len(anchor0a)
    anchor0b = '" id="image-zoom" src=""/>'
    anchor0b_idx = soup_s.find(anchor0b)

    url_precursor = "http://www.sothebys.com"
    img_url = url_precursor + soup_s[anchor0a_idx:anchor0b_idx]

    img_data = requests.get(img_url, headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.107 Safari/537.36','Upgrade-Insecure-Requests': '1','x-runtime': '148ms'}, allow_redirects=True).content
    img_name = str(auctionId) + '_' + str(lot) + '.jpg'
    with open(img_name, 'wb') as handler:
        handler.write(img_data)

    anchor1 = '<div class="lotdetail-description-text">'
    anchor2 = '</div>'
    anchor3 = 'lotdetail-section-sub-header">'
    anchor4 = '</div>'

    if soup_s.find(anchor1) != -1:
        soup_s1 = soup_s[soup_s.find(anchor1)+len(anchor1):]
        soup_s2 = soup_s1[:soup_s1.find(anchor2)]
    else:
        soup_s2 = ''
        
    if soup_s.find(anchor3) != -1:
        soup_s3 = soup_s[soup_s.find(anchor3)+len(anchor3):]
        soup_s4 = soup_s3[:soup_s3.find(anchor4)]
    else:
        soup_s4 = ''
    
    soup_s5 = soup_s2 + soup_s4
    
    soup_s5 = soup_s5.replace("<h3 class=\"lotdetail-section-sub-header\">",'')

    description = ' '.join(soup_s5.split())
    description = re.sub('<div class="readmore-content">', ' ', description)
    
    return description

# %%
def pull_all_descriptions(startRow, endRow, dataFrame):
    if input('are you sure you want to start the batch? all existing descriptions will be lost') == "yes":
        l = []
        time1 = time.time()
        
        for row in range(startRow,endRow):
            print "Pulling desc for lot #" + str(row)
            l.append(extract_lot_description(dataFrame['id'][row], dataFrame['auctionId'][row], dataFrame['auctionYear'][row]))

        dataFrame['lot_desc'][startRow:endRow] = l
        time2 = time.time()
        print("time to complete: " + str((time2-time1)/60/60) + " hours")
        print("time per problem: " + str((time2-time1)/(endRow-startRow)))

# %%
import sys

# df = masterdf_AuctionItems

def distribute_lot_desc_extr(df, startrow, endrow):

    def runSimulation(row):

        print "Pulling desc for lot #" + str(row)
        description = extract_lot_description(df['id'][row], df['auctionId'][row],df['auctionYear'][row])
        return description

    if __name__ == '__main__':

        numRows = startrow-endrow
        pool = mp.Pool(mp.cpu_count())
        time1 = time.time()
        results = pool.map_async(runSimulation, range(0,numRows), chunksize=10).get(99999)

        time2 = time.time()
        print("time to complete: " + str((time2-time1)/60/60) + " hours")
        print("time per problem: " + str((time2-time1)/numRows))
        df['lot_desc'][range(0,numRows)] = results

# %%
 pull_all_descriptions(0, 500, masterdf_AuctionItems)
# Out:
# are you sure you want to start the batch? all existing descriptions will be lost"yes"
# Pulling desc for lot #0
# Pulling desc for lot #1
# Pulling desc for lot #2
# Pulling desc for lot #3
# Pulling desc for lot #4
# Pulling desc for lot #5
# Pulling desc for lot #6
# Pulling desc for lot #7
# Pulling desc for lot #8
# Pulling desc for lot #9
# Pulling desc for lot #10
# Pulling desc for lot #11
# Pulling desc for lot #12
# Pulling desc for lot #13
# Pulling desc for lot #14
# Pulling desc for lot #15
# Pulling desc for lot #16
# Pulling desc for lot #17
# Pulling desc for lot #18
# Pulling desc for lot #19
# Pulling desc for lot #20
# Pulling desc for lot #21
# Pulling desc for lot #22
# Pulling desc for lot #23
# Pulling desc for lot #24
# Pulling desc for lot #25
# Pulling desc for lot #26
# Pulling desc for lot #27
# Pulling desc for lot #28
# Pulling desc for lot #29
# Pulling desc for lot #30
# Pulling desc for lot #31
# Pulling desc for lot #32
# Pulling desc for lot #33
# Pulling desc for lot #34
# Pulling desc for lot #35
# Pulling desc for lot #36
# Pulling desc for lot #37
# Pulling desc for lot #38
# Pulling desc for lot #39
# Pulling desc for lot #40
# Pulling desc for lot #41
# Pulling desc for lot #42
# Pulling desc for lot #43
# Pulling desc for lot #44
# Pulling desc for lot #45
# Pulling desc for lot #46
# Pulling desc for lot #47
# Pulling desc for lot #48
# Pulling desc for lot #49
# Pulling desc for lot #50
# Pulling desc for lot #51
# Pulling desc for lot #52
# Pulling desc for lot #53
# Pulling desc for lot #54
# Pulling desc for lot #55
# Pulling desc for lot #56
# Pulling desc for lot #57
# Pulling desc for lot #58
# Pulling desc for lot #59
# Pulling desc for lot #60
# Pulling desc for lot #61
# Pulling desc for lot #62
# Pulling desc for lot #63
# Pulling desc for lot #64
# Pulling desc for lot #65
# Pulling desc for lot #66
# Pulling desc for lot #67
# Pulling desc for lot #68
# Pulling desc for lot #69
# Pulling desc for lot #70
# Pulling desc for lot #71
# Pulling desc for lot #72
# Pulling desc for lot #73
# Pulling desc for lot #74
# Pulling desc for lot #75
# Pulling desc for lot #76
# Pulling desc for lot #77
# Pulling desc for lot #78
# Pulling desc for lot #79
# Pulling desc for lot #80
# Pulling desc for lot #81
# Pulling desc for lot #82
# Pulling desc for lot #83
# Pulling desc for lot #84
# Pulling desc for lot #85
# Pulling desc for lot #86
# Pulling desc for lot #87
# Pulling desc for lot #88

# %%
# Out:
#      auctionDate                                          auctionId  \
# 400  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 401  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 402  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 403  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 404  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 405  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 406  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 407  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 408  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 409  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 410  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 411  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 412  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 413  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 414  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 415  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 416  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 417  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 418  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 419  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 420  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 421  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 422  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 423  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 424  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 425  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 426  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 427  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 428  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 429  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# ..           ...                                                ...
# 470  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 471  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 472  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 473  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 474  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 475  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 476  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 477  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 478  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 479  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 480  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 481  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 482  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 483  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 484  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 485  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 486  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 487  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 488  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 489  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 490  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 491  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 492  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 493  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 494  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 495  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 496  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 497  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 498  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
# 499  19 JAN 2017  americana-collection-george-s-parker-ii-caxamb...
#
#                                            auctionName currency  \
# 400  The Highly Important Americana Collection of G...      USD
# 401  The Highly Important Americana Collection of G...      USD
# 402  The Highly Important Americana Collection of G...      USD
# 403  The Highly Important Americana Collection of G...      USD
# 404  The Highly Important Americana Collection of G...      USD
# 405  The Highly Important Americana Collection of G...      USD
# 406  The Highly Important Americana Collection of G...      USD
# 407  The Highly Important Americana Collection of G...      USD
# 408  The Highly Important Americana Collection of G...      USD
# 409  The Highly Important Americana Collection of G...      USD
# 410  The Highly Important Americana Collection of G...      USD
# 411  The Highly Important Americana Collection of G...      USD
# 412  The Highly Important Americana Collection of G...      USD
# 413  The Highly Important Americana Collection of G...      USD
# 414  The Highly Important Americana Collection of G...      USD
# 415  The Highly Important Americana Collection of G...      USD
# 416  The Highly Important Americana Collection of G...      USD
# 417  The Highly Important Americana Collection of G...      USD
# 418  The Highly Important Americana Collection of G...      USD
# 419  The Highly Important Americana Collection of G...      USD
# 420  The Highly Important Americana Collection of G...      USD
# 421  The Highly Important Americana Collection of G...      USD
# 422  The Highly Important Americana Collection of G...      USD
# 423  The Highly Important Americana Collection of G...      USD
# 424  The Highly Important Americana Collection of G...      USD
# 425  The Highly Important Americana Collection of G...      USD
# 426  The Highly Important Americana Collection of G...      USD
# 427  The Highly Important Americana Collection of G...      USD
# 428  The Highly Important Americana Collection of G...      USD
# 429  The Highly Important Americana Collection of G...      USD
# ..                                                 ...      ...
# 470  The Highly Important Americana Collection of G...      USD
# 471  The Highly Important Americana Collection of G...      USD
# 472  The Highly Important Americana Collection of G...      USD
# 473  The Highly Important Americana Collection of G...      USD
# 474  The Highly Important Americana Collection of G...      USD
# 475  The Highly Important Americana Collection of G...      USD
# 476  The Highly Important Americana Collection of G...      USD
# 477  The Highly Important Americana Collection of G...      USD
# 478  The Highly Important Americana Collection of G...      USD
# 479  The Highly Important Americana Collection of G...      USD
# 480  The Highly Important Americana Collection of G...      USD
# 481  The Highly Important Americana Collection of G...      USD
# 482  The Highly Important Americana Collection of G...      USD
# 483  The Highly Important Americana Collection of G...      USD
# 484  The Highly Important Americana Collection of G...      USD
# 485  The Highly Important Americana Collection of G...      USD
# 486  The Highly Important Americana Collection of G...      USD
# 487  The Highly Important Americana Collection of G...      USD
# 488  The Highly Important Americana Collection of G...      USD
# 489  The Highly Important Americana Collection of G...      USD
# 490  The Highly Important Americana Collection of G...      USD
# 491  The Highly Important Americana Collection of G...      USD
# 492  The Highly Important Americana Collection of G...      USD
# 493  The Highly Important Americana Collection of G...      USD
# 494  The Highly Important Americana Collection of G...      USD
# 495  The Highly Important Americana Collection of G...      USD
# 496  The Highly Important Americana Collection of G...      USD
# 497  The Highly Important Americana Collection of G...      USD
# 498  The Highly Important Americana Collection of G...      USD
# 499  The Highly Important Americana Collection of G...      USD
#
#                          genre  \
# 400             [18th century]
# 401   [George I, 18th century]
# 402   [George I, 18th century]
# 403   [George I, 18th century]
# 404  [George II, 18th century]
# 405   [George I, 18th century]
# 406   [George I, 18th century]
# 407               [Queen Anne]
# 408               [Queen Anne]
# 409                  [Realist]
# 410               [Queen Anne]
# 411               [Queen Anne]
# 412               [Queen Anne]
# 413                  [Realist]
# 414               [Queen Anne]
# 415              [Chippendale]
# 416              [Chippendale]
# 417                [George II]
# 418              [Chippendale]
# 419              [Chippendale]
# 420               [Queen Anne]
# 421              [Chippendale]
# 422               [Queen Anne]
# 423              [Chippendale]
# 424               [Queen Anne]
# 425              [Chippendale]
# 426               [Queen Anne]
# 427               [Queen Anne]
# 428               [Queen Anne]
# 429              [Chippendale]
# ..                         ...
# 470              [Chippendale]
# 471              [Chippendale]
# 472              [Chippendale]
# 473              [Chippendale]
# 474              [Chippendale]
# 475              [Chippendale]
# 476              [Chippendale]
# 477              [Chippendale]
# 478              [Chippendale]
# 479              [Chippendale]
# 480              [Chippendale]
# 481                  [Realist]
# 482              [Chippendale]
# 483              [Chippendale]
# 484              [Chippendale]
# 485              [Chippendale]
# 486                  [Realist]
# 487              [Chippendale]
# 488                  [Realist]
# 489               [George III]
# 490               [George III]
# 491              [Chippendale]
# 492               [George III]
# 493                  [Realist]
# 494                  [Federal]
# 495                    [Other]
# 496               [Queen Anne]
# 497                  [Realist]
# 498                  [Federal]
# 499                  [Federal]
#
#                                          guaranteeLine  highEst    id isSold  \
# 400  A GEORGE II SILVER TAPERSTICK, WILLIAM GOULD, ...     1800  2077   True
# 401  A GEORGE I�SILVER TAPERSTICK, NICHOLAS CLAUSEN...     1500  2078  False
# 402  A GEORGE I�SILVER BASTING SPOON, JOSEPH SMITH,...     1200  2079  False
# 403  A GEORGE I�SILVER BOWL, THOMAS MASON, LONDON, ...     3000  2080   True
# 404  A GEORGE II�SILVER SMALL BRANDY WARMER, JOHN G...     1500  2081   True
# 405  A PAIR OF GEORGE I SILVER CANDLESTICKS, THOMAS...     8000  2082   True
# 406  A PAIR OF GEORGE I�SILVER CASTERS, GLOVER JOHN...     6000  2083  False
# 407  IMPORTANT QUEEN ANNE CARVED WALNUT COMPASS-SEA...    80000  2084   True
# 408  VERY RARE QUEEN ANNE CARVED WALNUT COMPASS-SEA...    80000  2085   True
# 409            ATTRIBUTED TO JOSEPH BADGER (1708-1763)    10000  2086   True
# 410  VERY FINE AND RARE QUEEN ANNE CEDARWOOD SLANT-...    15000  2087   True
# 411  FINE AND RARE�QUEEN ANNE SHELL-CARVED MAHOGANY...    30000  2088   True
# 412  IMPORTANT�QUEEN ANNE CARVED AND FIGURED MAHOGA...   500000  2089   True
# 413               JOSEPH BLACKBURN (C. 1730 - C. 1778)    25000  2090  False
# 414  FINE QUEEN ANNE CHERRYWOOD CANDLESTAND, NEW EN...     1500  2091   True
# 415  FINE AND RARE�CHIPPENDALE WALNUT EASY CHAIR, B...     7000  2092   True
# 416  CHIPPENDALE CARVED AND FIGURED MAHOGANY DROP-L...     2500  2093   True
# 417  GEORGE II PARCEL-GILT AND MAHOGANY LOOKING GLA...     3000  2094   True
# 418  FINE CHIPPENDALE CARVED AND FIGURED MAHOGANY R...    12000  2095   True
# 419  VERY FINE CHIPPENDALE CARVED MAHOGANY SLANT-FR...    30000  2096   True
# 420  FINE QUEEN ANNE FIGURED MAHOGANY TILT-TOP CAND...     2500  2097   True
# 421  FINE CHIPPENDALE CARVED AND FIGURED MAHOGANY S...     5000  2098   True
# 422  FINE QUEEN ANNE CARVED CHERRYWOOD DRESSING TAB...     8000  2099   True
# 423  FINE AND RARE CHIPPENDALE WALNUT EASY CHAIR, B...    10000  2100   True
# 424  FINE QUEEN ANNE MAHOGANY PORRINGER-TOP TABLE, ...     4000  2101   True
# 425  FINE CHIPPENDALE FIGURED MAHOGANY SERPENTINE-F...     6000  2102   True
# 426  QUEEN ANNE MAPLE SINGLE-DRAWER TAVERN TABLE, N...     1500  2103   True
# 427  QUEEN ANNE GRAY-PAINTED MAPLE PENCIL-POST BEDS...     5000  2104  False
# 428  QUEEN ANNE INLAID CHERRYWOOD HIGH CHEST OF DRA...     5000  2105   True
# 429  FINE CHIPPENDALE CARVED CHERRYWOOD SERPENTINE-...    10000  2106   True
# ..                                                 ...      ...   ...    ...
# 470  FINE CHIPPENDALE CARVED MAHOGANY MARLBOROUGH-F...    12000  2147   True
# 471  IMPORTANT PAIR OF CHIPPENDALE CARVED AND FIGUR...   300000  2148   True
# 472  VERY FINE AND RARE CHIPPENDALE CARVED MAHOGANY...   120000  2149   True
# 473  RARE CHIPPENDALE WALNUT SUGAR CHEST, PHILADELP...     3500  2150   True
# 474  VERY FINE AND RARE CHIPPENDALE CARVED MAHOGANY...    10000  2151   True
# 475  VERY FINE AND RARE CHIPPENDALE CARVED MAHOGANY...    25000  2152   True
# 476  VERY RARE CHIPPENDALE CARVED AND FIGURED MAHOG...    50000  2153   True
# 477  VERY FINE AND RARE CHIPPENDALE CARVED AND FIGU...   120000  2154  False
# 478  CHIPPENDALE CARVED MAHOGANY SIDE CHAIR, CARVIN...    12000  2155   True
# 479  FINE CHIPPENDALE CARVED MAHOGANY SIDE CHAIR, C...    12000  2156  False
# 480  CHIPPENDALE CARVED MAHOGANY SIDE CHAIR, CARVIN...    12000  2157  False
# 481    ATTRIBUTED TO ROBERT EDGE PINE (C. 1730 - 1788)     7000  2158   True
# 482  VERY FINE AND RARE CHIPPENDALE CARVED AND FIGU...    25000  2159   True
# 483  THE IMPORTANT CHARLES THOMSON CHIPPENDALE CARV...   300000  2160  False
# 484  VERY FINE AND RARE CHIPPENDALE CARVED AND FIGU...   120000  2161   True
# 485  CHIPPENDALE CARVED AND FIGURED MAHOGANY HIGH C...    50000  2162   True
# 486  ATTRIBUTED TO JOHN SINGLETON COPLEY (1738 - 1815)    15000  2163   True
# 487  RARE CHIPPENDALE CARVED AND FIGURED MAHOGANY D...    30000  2164  False
# 488                       AFTER CHARLES WILLSON PEALE)    10000  2165   True
# 489  PAIR OF GEORGE III BRASS DOOR KNOCKERS, ENGLAN...      150  2166   True
# 490  VERY FINE GEORGE III ENGRAVED AND PIERCED BRAS...     1200  2167   True
# 491  GEORGE II PARCEL-GILT AND MAHOGANY LOOKING GLA...     1200  2168  False
# 492  GEORGE III MAHOGANY PIER TABLE, POSSIBLY IRISH...     3000  2169   True
# 493                CHARLES WILLSON PEALE (1741 - 1827)    50000  2170   True
# 494  PAIR OF FEDERAL CAST BRASS AND WROUGHT IRON "A...      800  2171   True
# 495  FINE BLACK-PAINTED CONTINUOUS-ARM WINDSOR CHAI...     2000  2172   True
# 496  FINE AND RARE QUEEN ANNE TURNED MAPLE &#39;FID...     1200  2173   True
# 497                           RALPH EARL (1751 - 1801)    15000  2174   True
# 498  FEDERAL CARVED MAHOGANY OPEN ARMCHAIR, NEW YOR...     1200  2175   True
# 499  RARE FEDERAL INLAID AND FIGURED MAHOGANY DROP-...     5000  2176   True
#
#      lowEst             medium  salePrice  \
# 400    1200           [Silver]       1250
# 401    1000           [Silver]          0
# 402     800           [Silver]        625
# 403    2000           [Silver]       1875
# 404    1200     [Silver, Wood]       1125
# 405    6000           [Silver]       3250
# 406    4000           [Silver]       3500
# 407   60000           [Walnut]      93750
# 408   50000           [Walnut]      43750
# 409    8000    [Oil on canvas]      15000
# 410   10000             [Wood]      15000
# 411   20000           [Walnut]      50000
# 412  300000         [Mahogany]     672500
# 413   15000    [Oil on canvas]       8125
# 414    1000       [Cherrywood]        625
# 415    5000           [Walnut]       3250
# 416    1500         [Mahogany]       1875
# 417    2000  [Glass, Mahogany]       2500
# 418    6000         [Mahogany]       4375
# 419   20000         [Mahogany]      47500
# 420    1500         [Mahogany]       1000
# 421    3000         [Mahogany]       2750
# 422    6000       [Cherrywood]       6250
# 423    6000           [Walnut]       5250
# 424    2000         [Mahogany]       5625
# 425    4000         [Mahogany]       3750
# 426    1000            [Maple]       1625
# 427    3000            [Maple]       2750
# 428    3000       [Cherrywood]       8125
# 429    5000       [Cherrywood]       5625
# ..      ...                ...        ...
# 470    8000         [Mahogany]       8750
# 471  200000         [Mahogany]     324500
# 472   80000         [Mahogany]     150000
# 473    2500           [Walnut]       5250
# 474    6000         [Mahogany]      13750
# 475   15000         [Mahogany]      12500
# 476   30000         [Mahogany]      25000
# 477   80000         [Mahogany]      68750
# 478    8000         [Mahogany]       7500
# 479    8000         [Mahogany]       6000
# 480    8000         [Mahogany]       6000
# 481    5000    [Oil on canvas]      11250
# 482   15000         [Mahogany]       2750
# 483  200000         [Mahogany]     175000
# 484   80000         [Mahogany]      62500
# 485   25000         [Mahogany]      18750
# 486   10000    [Oil on canvas]      22500
# 487   15000         [Mahogany]      11875
# 488    8000    [Oil on canvas]      43750
# 489     100            [Brass]       1500
# 490     800            [Brass]        875
# 491     800         [Mahogany]        313
# 492    1500         [Mahogany]      12500
# 493   30000    [Oil on canvas]      75000
# 494     600            [Brass]       2250
# 495    1000             [Wood]        625
# 496     800            [Maple]       4375
# 497   10000    [Oil on canvas]      27500
# 498     800         [Mahogany]        875
# 499    3000         [Mahogany]       8750
#
#                                                 title  \
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409                           PORTRAIT OF ISAAC JONES
# 410
# 411
# 412
# 413                          PORTRAIT OF THOMAS AMORY
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# ..                                                ...
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# 481      PORTRAIT OF A BRITISH OFFICER IN RED UNIFORM
# 482
# 483
# 484
# 485
# 486                           PORTRAIT OF�A GENTLEMAN
# 487
# 488   GEORGE WASHINGTON AFTER THE BATTLE OF PRINCETON
# 489
# 490
# 491
# 492
# 493  MR. AND MRS. THOMAS RUSSELL: A PAIR OF PORTRAITS
# 494
# 495
# 496
# 497                   PORTRAIT OF MAJOR JAMES FAIRLIE
# 498
# 499
#
#                               type  auctionYear  \
# 400                     [Lighting]         2017
# 401                     [Lighting]         2017
# 402                     [Flatware]         2017
# 403             [Basket and bowls]         2017
# 404                      [Alcohol]         2017
# 405                     [Lighting]         2017
# 406  [Salt, spice, oil and pepper]         2017
# 407                        [Chair]         2017
# 408                        [Chair]         2017
# 409                     [Portrait]         2017
# 410                         [Desk]         2017
# 411                        [Chair]         2017
# 412                        [Table]         2017
# 413                     [Portrait]         2017
# 414                        [Table]         2017
# 415                        [Chair]         2017
# 416                        [Table]         2017
# 417                [Looking glass]         2017
# 418                        [Chest]         2017
# 419                         [Desk]         2017
# 420                        [Table]         2017
# 421                        [Chair]         2017
# 422                        [Table]         2017
# 423                        [Chair]         2017
# 424                        [Table]         2017
# 425                        [Chest]         2017
# 426                        [Table]         2017
# 427                     [Bedstead]         2017
# 428                        [Chest]         2017
# 429                        [Chest]         2017
# ..                             ...          ...
# 470                     [Bedstead]         2017
# 471                        [Chair]         2017
# 472                        [Chair]         2017
# 473                        [Chest]         2017
# 474                        [Other]         2017
# 475                        [Chair]         2017
# 476                        [Other]         2017
# 477                        [Table]         2017
# 478                        [Chair]         2017
# 479                        [Chair]         2017
# 480                        [Chair]         2017
# 481                     [Portrait]         2017
# 482                        [Table]         2017
# 483                        [Chair]         2017
# 484                        [Table]         2017
# 485                        [Chest]         2017
# 486                     [Portrait]         2017
# 487                        [Table]         2017
# 488                     [Portrait]         2017
# 489                [Architectural]         2017
# 490                    [Fireplace]         2017
# 491                [Looking glass]         2017
# 492                        [Table]         2017
# 493                     [Portrait]         2017
# 494                        [Other]         2017
# 495                        [Chair]         2017
# 496                        [Chair]         2017
# 497                     [Portrait]         2017
# 498                        [Chair]         2017
# 499                        [Table]         2017
#
#                                               lot_desc
# 400  shaped and molded base, octagonal baluster ste...
# 401  square molded base with cut corners, circular ...
# 402  with oval rat-tail bowl and turned-up tip to h...
# 403  with molded foot and rim, the base with pricke...
# 404  bomb form with short spout and turned handle m...
# 405  the molded square bases with incurved corners,...
# 406  octagonal baluster form, slip-on covers pierce...
# 407  sea trail and slip seat marked I, proper left ...
# 408  seat inscribed Perot, proper right rear leg re...
# 409  oil on canvas 38 1/4 by 28 5/8 in. circa 1756 ...
# 410  Height 41 1/2 in. by Width 37 3/4 in. by Depth...
# 411  chair marked VI , slip seat marked I, base of ...
# 412  appears to retain its original hardware. Heigh...
# 413  signed JBlackburn Pinxi<sup>t</sup> and dated ...
# 414  Height 28 1/4 in. by Width 16 1/4 in. by Depth...
# 415                                  Height 45 1/2 in.
# 416  Height 28 in. by Width 18 in. (closed) by Dept...
# 417              Height 53 1/2 in. by Width 26 1/2 in.
# 418  appears to retain its original cast brass hard...
# 419  incised JC on proper left letter drawer, appea...
# 420  Height 26 in. by Width 15 3/4 in. by Depth 16 ...
# 421  chair marked XV , rear seat rail marked R. Boy...
# 422  Height 30 in. by Width 35 3/4 in. by Depth 20 ...
# 423          side knee returns replaced. Height 48 in.
# 424  Height 26 in. by Width 34 1/2 in. by Depth 24 in.
# 425  Height 32 3/4 in. by Width 42 1/4 in. by Depth...
# 426  Height 28 in. by Width 37 in. by Depth 22 1/4 in.
# 427  head and end rails replaced. Height 78 in. by ...
# 428  appears to retain its original hardware, feet ...
# 429  Height 34 1/2 in. by Width 43 1/4 in. by Depth...
# ..                                                 ...
# 470  retains original headboard and rails. Height 9...
# 471  Height 39 1/2 in. Provenance  Both: Stoudts Bl...
# 472  chair and slip seat marked VII. Height 40 1/4 ...
# 473  Height 20 3/4 in. by Width 16 3/4 in. by Depth...
# 474  Height 52 1/4 in. by Width 17 3/4 in. by Depth...
# 475  chair marked V. Height 38 1/2 in. Provenance  ...
# 476  numbered 2307, works probably associated, fini...
# 477  Height 28 in. by Width 28 1/2 in. by Depth 38 ...
# 478  retains a dark rich historic surface, marked I...
# 479  slip seat and chair marked VI. Height 38 1/2 i...
# 480    slip seat and chair marked V. Height 38 1/2 in.
# 481  oil on canvas 30 by 24 1/2 in. Provenance  Ear...
# 482  Height 29 in. by Width 31 1/8 in. by Depth 30 ...
# 483  retains a rich historic surface, approximately...
# 484  retains a rich historic surface, front and bac...
# 485  finial, cartouche and legs replaced. Height 97...
# 486  oil on canvas 30 by 24 3/4 in. circalate 1760s...
# 487  Height 27 3/4 in. by Width 32 1/2 in. by Depth...
# 488  oil on canvas 40 1/2 by 28 3/4 in. Literature ...
# 489  mounted on white-painted wood plaques. Height ...
# 490                  Height 5 1/2 in. by Length 54 in.
# 491  proper lower right scroll element lacking. Hei...
# 492  Height 33 in. by Width 60 in. by Depth 19 1/2 in.
# 493  oil on canvas each: 30 by 25 in. 1784 Provenan...
# 494  together with matching fireplace tongs andshov...
# 495  black paint over apparent original green paint...
# 496  marked D. Coutong, appears to retain its origi...
# 497  oil on canvas 25 1/2 by 21 5/8 in. Provenance ...
# 498                                  Height 38 1/4 in.
# 499  Height 27 in. by Width 18 1/4 in. by Depth 32 ...
#
# [100 rows x 16 columns]

# %%
masterdf_AuctionItems.to_csv('auctionItems.csv', index=True, header=True)

# %%
<img id="image-zoom" class="lot-image" data-src="/content/dam/stb/lots/N09/N09633/208N09633_9BFBW.jpg" src="">
# Out:
#    auctionDate            auctionId   auctionName currency       genre  \
# 1  07 APR 2017  american-art-n09633  American Art      USD  [American]
#
#   guaranteeLine  highEst  id isSold  lowEst                        medium  \
# 1  MILTON AVERY    25000  10   True   15000  [Body colour/gouache, Paper]
#
#    salePrice    title                  type  auctionYear  \
# 1      15000  BOUQUET  [Flower, Still life]         2017
#
#                                             lot_desc
# 1  signed MILTON AVERY (center right); signed Mil...
